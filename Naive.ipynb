# %%
import numpy as np
import pandas as pd
import nltk as nl
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
c_df = pd.read_csv('creature_vector.csv', index_col=[0])
n_df = pd.read_csv('noncreature_vector.csv', index_col=[0])

# %%
c_df = c_df.reset_index(drop=True)
n_df = n_df.reset_index(drop=True)

# %%
c_df
# Out:
#                           name  mana_cost  cmc  \
# 0                   Storm Crow     {1}{U}  2.0
# 1               Walking Sponge     {1}{U}  2.0
# 2                  Pteramander        {U}  1.0
# 3                Nantuko Elder     {2}{G}  3.0
# 4             Vedalken Heretic     {G}{U}  2.0
# ...                        ...        ...  ...
# 11609             Venom Sliver     {1}{G}  2.0
# 11610        Borderland Ranger     {2}{G}  3.0
# 11611            Quarry Beetle     {4}{G}  5.0
# 11612             Devoted Hero        {W}  1.0
# 11613  Firesong and Sunspeaker  {4}{R}{W}  6.0
#
#                                              oracle_text  power  toughness  \
# 0      Flying (This creature can't be blocked except ...    1.0        2.0
# 1      {T}: Target creature loses your choice of flyi...    1.0        1.0
# 2      Flying {7}{U}: Adapt 4. This ability costs {1}...    1.0        1.0
# 3                                       {T}: Add {C}{G}.    1.0        2.0
# ...

# %%
n_df
# Out:
#                       name  mana_cost  cmc  \
# 0               Static Orb        {3}  3.0
# 1      Sensory Deprivation        {U}  1.0
# 2           Road of Return     {G}{G}  2.0
# 3           Ravnica at War     {3}{W}  4.0
# 4          Torrent of Fire  {3}{R}{R}  5.0
# ...                    ...        ...  ...
# 10326      Curse of Thirst     {4}{B}  5.0
# 10327      Temporary Truce     {1}{W}  2.0
# 10328    Clearwater Goblet        {5}  5.0
# 10329     Without Weakness     {1}{B}  2.0
# 10330    Samut, the Tested  {2}{R}{G}  4.0
#
#                                              oracle_text  prices  set  rarity  \
# 0      As long as This Card is untapped  players can'...   20.58  7ed       2
# 1        Enchant creature Enchanted creature gets -3/-0.    0.04  m14       0
# 2      Choose one — • Return target permanent card fr...    0.24  c19       2
# 3                     Exile all multicolored permanents.    0.23  war       2
# ...

# %%
creature_features = c_df['features'].values
train, test = train_test_split(creature_features)

# %%
len(train)
# Out:
# 8710

# %%
len(test)
# Out:
# 2904

# %%
creature_classifier = nl.NaiveBayesClassifier.train(train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 creature_classifier = nl.NaiveBayesClassifier.train(train)
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\nltk\classify\naivebayes.py:210, in NaiveBayesClassifier.train(cls, labeled_featuresets, estimator)
#     206 fnames = set()
#     208 # Count up how many times each feature value occurred, given
#     209 # the label and featurename.
# --> 210 for featureset, label in labeled_featuresets:
#     211     label_freqdist[label] += 1
#     212     for fname, fval in featureset.items():
#     213         # Increment freq(fval|label, fname)
#
# ValueError: too many values to unpack (expected 2)

# %%
train.shape
# Out:
# (8710,)
