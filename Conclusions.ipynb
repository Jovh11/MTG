# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
forest = {'Random Forest Classifier': 95.59}
gaussian = {'Gaussian Naive Bayes': 31.77}
multinomial = {'Multinomial Naive Bayes': 94.21}
deep = {'Deep Learning Model': 95.82}

# %%
c = pd.DataFrame([forest, gaussian, multinomial, deep])

# %%
c.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
nforest = {'Random Forest Classifier': 91.25}
ngaussian = {'Gaussian Naive Bayes': 29.33}
nmulti = {'Multinomial Naive Bayes': 88.39}

# %%
nc = pd.DataFrame([nforest, ngaussian, nmulti])

# %%
nc.plot(kind='bar')
# Out:
# <AxesSubplot:>
