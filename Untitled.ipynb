# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
c_df = pd.read_csv('creature_vector.csv', index_col=[0])
n_df = pd.read_csv('noncreature_vector.csv', index_col=[0])

# %%
c_df = c_df.reset_index(drop=True)
n_df = n_df.reset_index(drop=True)

# %%
c_df
# Out:
#                           name  mana_cost  cmc  \
# 0                   Storm Crow     {1}{U}    2
# 1               Walking Sponge     {1}{U}    2
# 2                  Pteramander        {U}    1
# 3                Nantuko Elder     {2}{G}    3
# 4             Vedalken Heretic     {G}{U}    2
# ...                        ...        ...  ...
# 11609             Venom Sliver     {1}{G}    2
# 11610        Borderland Ranger     {2}{G}    3
# 11611            Quarry Beetle     {4}{G}    5
# 11612             Devoted Hero        {W}    1
# 11613  Firesong and Sunspeaker  {4}{R}{W}    6
#
#                                              oracle_text Label  power  \
# 0      Flying (This creature can't be blocked except ...     E      1
# 1      {T}: Target creature loses your choice of flyi...     A      1
# 2      Flying {7}{U}: Adapt 4. This ability costs {1}...     E      1
# 3                                       {T}: Add {C}{G}.     M      1
# ...

# %%
n_df
# Out:
#                       name  mana_cost  cmc  \
# 0               Static Orb        {3}  3.0
# 1      Sensory Deprivation        {U}  1.0
# 2           Road of Return     {G}{G}  2.0
# 3           Ravnica at War     {3}{W}  4.0
# 4          Torrent of Fire  {3}{R}{R}  5.0
# ...                    ...        ...  ...
# 10326      Curse of Thirst     {4}{B}  5.0
# 10327      Temporary Truce     {1}{W}  2.0
# 10328    Clearwater Goblet        {5}  5.0
# 10329     Without Weakness     {1}{B}  2.0
# 10330    Samut, the Tested  {2}{R}{G}  4.0
#
#                                              oracle_text  prices  set  rarity  \
# 0      As long as This Card is untapped  players can'...   20.58  7ed       2
# 1        Enchant creature Enchanted creature gets -3/-0.    0.04  m14       0
# 2      Choose one — • Return target permanent card fr...    0.24  c19       2
# 3                     Exile all multicolored permanents.    0.23  war       2
# ...

# %%
c_preprared = c_df[['cmc', 'power', 'toughness', 'rarity', 'features', 'prices']]
c_preprared
# Out:
#        cmc  power  toughness  rarity  \
# 0        2      1          2       0
# 1        2      1          1       1
# 2        1      1          1       1
# 3        3      1          2       1
# 4        2      1          1       2
# ...    ...    ...        ...     ...
# 11609    2      1          1       1
# 11610    3      2          2       0
# 11611    5      4          5       1
# 11612    1      1          2       0
# 11613    6      4          6       2
#
#                                                 features  prices
# 0        (0, 1968)0.22632719839767884  (0, 1772)0.105...    0.20
# 1        (0, 2001)0.1789750039701041  (0, 1881)0.2127...    0.15
# 2        (0, 2001)0.10733625502185658  (0, 1798)0.104...    0.15
# 3                                             (0, 30)1.0    0.56
# 4        (0, 2000)0.19020492101106837  (0, 1950)0.264...    0.26
# ...                                                  ...     ...
# ...

# %%
c_y = c_preprared['prices'].values
c_X = c_preprared.drop(['prices'], 1).values
# Out:
# C:\Users\rcrch\AppData\Local\Temp\ipykernel_28432\3979991464.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   c_X = c_preprared.drop(['prices'], 1).values

# %%
c_preprared.dtypes
# Out:
# cmc            int64
# power          int64
# toughness      int64
# rarity         int64
# features      object
# prices       float64
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(c_X, c_y, random_state=42)

# %%
scaler = StandardScaler()

# %%
X_scaler = scaler.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 X_scaler = scaler.fit(X_train)
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py:809, in StandardScaler.fit(self, X, y, sample_weight)
#     807 # Reset internal state before fitting
#     808 self._reset()
# --> 809 return self.partial_fit(X, y, sample_weight)
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py:844, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     812 """Online computation of mean and std on X for later scaling.
#     813
#     814 All of X is processed as a single batch. This is intended for cases
#    (...)
#     841     Fitted scaler.
#     842 """
#     843 first_call = not hasattr(self, "n_samples_seen_")
# --> 844 X = self._validate_data(
#     845     X,
# ...

# %%
test = c_df.iloc[0].features

# %%
c_df['features'] = c_df['features'].str.replace('\t', '')
c_df['features'] = c_df['features'].str.replace('\n', '')

# %%
c_df['features'].astype('float64')
c_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 c_df['features'].astype('float64')
#       2 c_df.dtypes
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidfvectorizer = TfidfVectorizer(analyzer='word' , stop_words='english',)
test2 = tfidfvectorizer.transform(test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Input In [35], in <cell line: 3>()
#       1 from sklearn.feature_extraction.text import TfidfVectorizer
#       2 tfidfvectorizer = TfidfVectorizer(analyzer='word' , stop_words='english',)
# ----> 3 test2 = tfidfvectorizer.transform(test)
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\feature_extraction\text.py:2101, in TfidfVectorizer.transform(self, raw_documents)
#    2085 def transform(self, raw_documents):
#    2086     """Transform documents to document-term matrix.
#    2087
#    2088     Uses the vocabulary and document frequencies (df) learned by fit (or
#    (...)
#    2099         Tf-idf-weighted document-term matrix.
#    2100     """
# -> 2101     check_is_fitted(self, msg="The TF-IDF vectorizer is not fitted")
#    2103     X = super().transform(raw_documents)
# ...
